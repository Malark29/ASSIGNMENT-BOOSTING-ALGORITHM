# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
dataset=pd.read_csv("insurance_pre.csv")

# %%
dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
dataset=pd.get_dummies(dataset,drop_first=True,dtype=int)

# %%
dataset
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400         0           1
# 1      18  33.770         1   1725.55230         1           0
# 2      28  33.000         3   4449.46200         1           0
# 3      33  22.705         0  21984.47061         1           0
# 4      32  28.880         0   3866.85520         1           0
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830         1           0
# 1334   18  31.920         0   2205.98080         0           0
# 1335   18  36.850         0   1629.83350         0           0
# 1336   21  25.800         0   2007.94500         0           0
# 1337   61  29.070         0  29141.36030         0           1
#
# [1338 rows x 6 columns]

# %%
indep=dataset[['age', 'bmi', 'children', 'sex_male', 'smoker_yes']]
dep=dataset['charges']

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.tree import DecisionTreeRegressor
param_grid = {'criterion':['squared_error','absolute_error','friedman_mse'],
              'max_features': [None,'sqrt','log2'],
              'max_depth':[None,5,10,20],
              'min_samples_split':[2,5,10]}

grid = GridSearchCV(DecisionTreeRegressor(random_state=42), param_grid, refit = True, verbose = 3,n_jobs=-1)


grid.fit(indep,dep)
# Out:
# Fitting 5 folds for each of 108 candidates, totalling 540 fits
# GridSearchCV(estimator=DecisionTreeRegressor(random_state=42), n_jobs=-1,
#              param_grid={'criterion': ['squared_error', 'absolute_error',
#                                        'friedman_mse'],
#                          'max_depth': [None, 5, 10, 20],
#                          'max_features': [None, 'sqrt', 'log2'],
#                          'min_samples_split': [2, 5, 10]},
#              verbose=3)

# %%
re=grid.cv_results_

print("The R_score value for best parameter {}:".format(grid.best_params_))
# Out:
# The R_score value for best parameter {'criterion': 'absolute_error', 'max_depth': 5, 'max_features': None, 'min_samples_split': 2}:

# %%
table=pd.DataFrame.from_dict(re)

# %%
table
# Out:
#      mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0         0.025689      0.017738         0.021064        0.029228
# 1         0.032930      0.029619         0.010811        0.010298
# 2         0.013998      0.003544         0.005241        0.004632
# 3         0.013235      0.001869         0.004541        0.002538
# 4         0.008054      0.001810         0.006673        0.003912
# ..             ...           ...              ...             ...
# 103       0.009618      0.001557         0.014280        0.014240
# 104       0.010426      0.003349         0.007576        0.004182
# 105       0.012543      0.005531         0.003834        0.003377
# 106       0.007254      0.006762         0.004306        0.004256
# 107       0.011957      0.003018         0.001528        0.002163
#
#     param_criterion param_max_depth param_max_features  \
# 0     squared_error            None               None
# 1     squared_error            None               None
# ...

# %%
age_input=float(input("Age:"))
bmi_input=float(input("BMI"))
children_input=float(input("Children"))
sex_male_input=float(input("Sex Male 0 or 1:"))
smoker_yes_input=float(input("Smoker Yes 0 or 1:"))
# Out:
# Age: 50
# BMI 59
# Children 2
# Sex Male 0 or 1: 1
# Smoker Yes 0 or 1: 0

# %%
Future_Prediction=grid.predict([[age_input,bmi_input,children_input,sex_male_input,smoker_yes_input]])
print("Future_Prediction={}".format(Future_Prediction))
# Out:
# Future_Prediction=[10527.21875]
# C:\Anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
