# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
dataset=pd.read_csv("insurance_pre.csv")

# %%
dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
dataset=pd.get_dummies(dataset,drop_first=True,dtype=int)

# %%
dataset
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400         0           1
# 1      18  33.770         1   1725.55230         1           0
# 2      28  33.000         3   4449.46200         1           0
# 3      33  22.705         0  21984.47061         1           0
# 4      32  28.880         0   3866.85520         1           0
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830         1           0
# 1334   18  31.920         0   2205.98080         0           0
# 1335   18  36.850         0   1629.83350         0           0
# 1336   21  25.800         0   2007.94500         0           0
# 1337   61  29.070         0  29141.36030         0           1
#
# [1338 rows x 6 columns]

# %%
indep=dataset[['age', 'bmi', 'children', 'sex_male', 'smoker_yes']]
dep=dataset['charges']

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
from sklearn.model_selection import GridSearchCV
param_grid = {'criterion':['squared_error','absolute_error'],
              'max_features': [None,'sqrt','log2'],
              'n_estimators':[50,100],
              'max_depth':[None,10,20],
              'min_samples_split':[2,5]}


grid = GridSearchCV(RandomForestRegressor(random_state=42), param_grid, refit = True, verbose = 3,n_jobs=-1)


grid.fit(indep,dep)
# Out:
# Fitting 5 folds for each of 72 candidates, totalling 360 fits
# GridSearchCV(estimator=RandomForestRegressor(random_state=42), n_jobs=-1,
#              param_grid={'criterion': ['squared_error', 'absolute_error'],
#                          'max_depth': [None, 10, 20],
#                          'max_features': [None, 'sqrt', 'log2'],
#                          'min_samples_split': [2, 5],
#                          'n_estimators': [50, 100]},
#              verbose=3)

# %%
re=grid.cv_results_

print("The R_score value for best parameter {}:".format(grid.best_params_))
# Out:
# The R_score value for best parameter {'criterion': 'absolute_error', 'max_depth': 10, 'max_features': 'sqrt', 'min_samples_split': 5, 'n_estimators': 100}:

# %%
table=pd.DataFrame.from_dict(re)

# %%
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.263460      0.001362         0.011558        0.001523
# 1        0.632365      0.121904         0.022864        0.006696
# 2        0.290689      0.086239         0.013564        0.004956
# 3        0.865199      0.020127         0.029089        0.002734
# 4        0.396692      0.006347         0.020594        0.002271
# ..            ...           ...              ...             ...
# 67       2.494007      0.030541         0.027090        0.004786
# 68       1.345072      0.022675         0.021723        0.005746
# 69       2.722906      0.040622         0.031733        0.004223
# 70       1.236728      0.039188         0.016039        0.003373
# 71       2.125892      0.029882         0.023496        0.003080
#
#    param_criterion param_max_depth param_max_features  \
# 0    squared_error            None               None
# 1    squared_error            None               None
# 2    squared_error            None               None
# 3    squared_error            None               None
# 4    squared_error            None               sqrt
# ..             ...             ...                ...
# 67  absolute_error              20               sqrt
# 68  absolute_error              20               log2
# 69  absolute_error              20               log2
# 70  absolute_error              20               log2
# 71  absolute_error              20               log2
#
#     param_min_samples_split  param_n_estimators  \
# 0                         2                  50
# 1                         2                 100
# 2                         5                  50
# 3                         5                 100
# 4                         2                  50
# ..                      ...                 ...
# 67                        5                 100
# 68                        2                  50
# 69                        2                 100
# 70                        5                  50
# 71                        5                 100
#
#                                                params  split0_test_score  \
# 0   {'criterion': 'squared_error', 'max_depth': No...           0.847118
# 1   {'criterion': 'squared_error', 'max_depth': No...           0.849914
# 2   {'criterion': 'squared_error', 'max_depth': No...           0.859137
# 3   {'criterion': 'squared_error', 'max_depth': No...           0.861702
# 4   {'criterion': 'squared_error', 'max_depth': No...           0.858325
# ..                                                ...                ...
# 67  {'criterion': 'absolute_error', 'max_depth': 2...           0.870604
# 68  {'criterion': 'absolute_error', 'max_depth': 2...           0.858051
# 69  {'criterion': 'absolute_error', 'max_depth': 2...           0.859266
# 70  {'criterion': 'absolute_error', 'max_depth': 2...           0.867549
# 71  {'criterion': 'absolute_error', 'max_depth': 2...           0.870604
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.765868           0.852885           0.821096
# 1            0.769660           0.855520           0.818034
# 2            0.780378           0.867865           0.826548
# 3            0.781962           0.868634           0.824735
# 4            0.772534           0.861344           0.830506
# ..                ...                ...                ...
# 67           0.789985           0.871420           0.833404
# 68           0.778153           0.855017           0.830642
# 69           0.777614           0.859429           0.829976
# 70           0.789511           0.870005           0.832697
# 71           0.789985           0.871420           0.833404
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0            0.832023         0.823798        0.031051               68
# 1            0.836538         0.825933        0.030958               66
# 2            0.840854         0.834957        0.030828               44
# 3            0.844412         0.836289        0.031122               42
# 4            0.835050         0.831552        0.031940               62
# ..                ...              ...             ...              ...
# 67           0.851797         0.843442        0.030162               13
# 68           0.843264         0.833025        0.029091               51
# 69           0.839901         0.833237        0.030041               47
# 70           0.854762         0.842905        0.029791               21
# 71           0.851797         0.843442        0.030162               13
#
# [72 rows x 18 columns]

# %%
age_input=float(input("Age:"))
bmi_input=float(input("BMI"))
children_input=float(input("Children"))
sex_male_input=float(input("Sex Male 0 or 1:"))
smoker_yes_input=float(input("Smoker Yes 0 or 1:"))
# Out:
# Age: 34
# BMI 45
# Children 2
# Sex Male 0 or 1: 1
# Smoker Yes 0 or 1: 2

# %%
Future_Prediction=grid.predict([[age_input,bmi_input,children_input,sex_male_input,smoker_yes_input]])
print("Future_Prediction={}".format(Future_Prediction))
# Out:
# Future_Prediction=[41276.98011925]
# C:\Anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
